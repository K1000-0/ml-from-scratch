# %%
import random
import sys
sys.path.insert(0, '..')
import numpy as np  
import matplotlib.pyplot as plt
from src.linear_regression import LinearRegressionClosedForm
from data.synthetic import make_linear_data

# %%
random.seed(0)
x, y = make_linear_data()
print(x.shape)
print(y)
# Out:
# (100, 1)
# [ 6.6025092   9.66270506  6.57944631  3.82971957  3.7600556   3.82950664
#   5.775288   -0.76561313  3.94500735 11.09279852  6.23784919  7.30681886
#  -3.94855775  4.31002111 -0.6249913   2.55985631  1.49384078  7.77216568
#   5.30782524  9.71726232 10.45274632  5.30542469 -2.0441623  13.83776716
#   5.38911416 15.20279742  4.71012157  7.6321012  12.14847129  9.07172621
#  15.05710127 10.8490366  10.73972411  2.87704003  1.7164409  16.20002026
#   6.84741968  3.58155525 14.65643014  7.03541755  5.51274921  5.87829837
#   5.95123226  6.73566056  8.17345266 12.41300172  4.32532722 16.18366779
#   8.63417206  8.73559385  7.76331871 13.93903031 10.83926471  7.59914698
#   2.40703672 -1.09992195 15.82658615 14.72783553  6.17884847 13.72628654
#   3.00001707  9.29506782  3.35779385 17.3487643   5.84275243  4.50907102
#   3.90063656  6.91751804  1.97116841 -6.19570741  5.89263399 -0.14651998
#  13.7531115   2.75281792 10.31573514  8.98439738 13.14398253  4.71111621
# ...

# %%
model = LinearRegressionClosedForm()
model.fit(x,y)
model.w
# Out:
# array([4.20323916, 3.92797318])

# %%
model.predict(x)
# Out:
# array([ 9.0108397 , 10.7641695 ,  8.49161867,  4.84296099, 10.34118635,
#        11.01874589, 11.99590167,  9.58890386, 10.43317444,  5.23325444,
#         4.32554487,  6.80002637,  5.34515285,  8.43676547, 10.02260775,
#         9.28885019,  4.28728184,  4.92491715,  7.24547137,  8.03602204,
#         8.00208594,  9.02652384, 11.27032493,  8.4846384 ,  9.46224997,
#         9.29587879,  8.58535273,  6.76544599, 10.56119356, 11.966649  ,
#         8.20569317,  4.88455916,  9.75653412,  7.54668363,  7.07288508,
#        10.16731074,  5.63259131,  5.81304227,  8.27388575, 10.83480007,
#         8.70093505,  9.74550873,  4.52067619,  4.76990095,  6.78219772,
#         4.94050232,  8.29236565,  7.70934596,  7.73920152, 11.92275768,
#         4.7946759 ,  4.25372124, 10.47929699, 10.48683517,  9.98914573,
#         9.58322023, 11.84786359,  5.52532575,  6.84169485,  8.24050018,
#        10.52017253, 11.50060495,  4.86249634,  6.63181446,  5.71961009,
# ...
